# %%
# The data set used in this example is from http://archive.ics.uci.edu/ml/datasets/Wine+Quality
# P. Cortez, A. Cerdeira, F. Almeida, T. Matos and J. Reis.
# Modeling wine preferences by data mining from physicochemical properties. In Decision Support Systems, Elsevier, 47(4):547-553, 2009.
#! pip install --user mlflow
 
import os
import warnings
import sys
 
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import ElasticNet
 
import mlflow
import mlflow.sklearn
 
import logging
logging.basicConfig(level=logging.WARN)
logger = logging.getLogger(__name__)
 
 
def eval_metrics(actual, pred):
    rmse = np.sqrt(mean_squared_error(actual, pred))
    mae = mean_absolute_error(actual, pred)
    r2 = r2_score(actual, pred)
    return rmse, mae, r2
 
 
 
if __name__ == "__main__":
    warnings.filterwarnings("ignore")
    np.random.seed(40)
 
    # Read the wine-quality csv file from the URL
    csv_url =\
        'http://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv'
    try:
        data = pd.read_csv(csv_url, sep=';')
    except Exception as e:
        logger.exception(
            "Unable to download training & test CSV, check your internet connection. Error: %s", e)
 
    # Split the data into training and test sets. (0.75, 0.25) split.
    train, test = train_test_split(data)
 
    # The predicted column is "quality" which is a scalar from [3, 9]
    train_x = train.drop(["quality"], axis=1)
    test_x = test.drop(["quality"], axis=1)
    train_y = train[["quality"]]
    test_y = test[["quality"]]
 
    #alpha = float(sys.argv[1]) if len(sys.argv) > 1 else 0.5
    #l1_ratio = float(sys.argv[2]) if len(sys.argv) > 2 else 0.5
    alpha = 0.67#à changer
    l1_ratio = 0.3#à changer
#Note de Zakaria
    os.environ['MLFLOW_TRACKING_USERNAME'] = 'gmendozamb'
    os.environ['MLFLOW_TRACKING_PASSWORD'] = 'TpFinal'
    os.environ['AZURE_STORAGE_CONNECTION_STRING'] = 'DefaultEndpointsProtocol=https;AccountName=tpfinal;AccountKey=ofrYHwTX9xiXLfg+kP3phQBE+Q8zJECGRtKApzq4v1fvOyw/r933h8HKDRGSeKBzTX+VDP6ZQqPa+AStcfdIMQ==;EndpointSuffix=core.windows.net'

    mlflow.set_experiment(experiment_name="Default")
    mlflow.set_tracking_uri("http://20.151.236.36") 
 
    with mlflow.start_run():
        lr = ElasticNet(alpha=alpha, l1_ratio=l1_ratio, random_state=42)
        lr.fit(train_x, train_y)
 
        predicted_qualities = lr.predict(test_x)
 
        (rmse, mae, r2) = eval_metrics(test_y, predicted_qualities)
 
        print("Elasticnet model (alpha=%f, l1_ratio=%f):" % (alpha, l1_ratio))
        print("  RMSE: %s" % rmse)
        print("  MAE: %s" % mae)
        print("  R2: %s" % r2)
 
        mlflow.log_param("alpha", alpha)
        mlflow.log_param("l1_ratio", l1_ratio)
        mlflow.log_metric("rmse", rmse)
        mlflow.log_metric("r2", r2)
        mlflow.log_metric("mae", mae)
 
        mlflow.sklearn.log_model(lr, "model")
# Out:
# 2023/05/27 14:36:04 INFO mlflow.tracking.fluent: Experiment with name 'experiment2' does not exist. Creating a new experiment.
# ---------------------------------------------------------------------------
# RestException                             Traceback (most recent call last)
# /Users/gmendozamb/Desktop/cours/AEC-IA/MiseEnPlaceEcosystemeIA/TP-Final/Code/rl_tp.ipynb Cell 1 in <cell line: 32>()
#      <a href='vscode-notebook-cell:/Users/gmendozamb/Desktop/cours/AEC-IA/MiseEnPlaceEcosystemeIA/TP-Final/Code/rl_tp.ipynb#W0sZmlsZQ%3D%3D?line=62'>63</a> mlflow.set_experiment(experiment_name="experiment2")
#      <a href='vscode-notebook-cell:/Users/gmendozamb/Desktop/cours/AEC-IA/MiseEnPlaceEcosystemeIA/TP-Final/Code/rl_tp.ipynb#W0sZmlsZQ%3D%3D?line=63'>64</a> mlflow.set_tracking_uri("http://20.151.236.36")
# ---> <a href='vscode-notebook-cell:/Users/gmendozamb/Desktop/cours/AEC-IA/MiseEnPlaceEcosystemeIA/TP-Final/Code/rl_tp.ipynb#W0sZmlsZQ%3D%3D?line=65'>66</a> with mlflow.start_run():
#      <a href='vscode-notebook-cell:/Users/gmendozamb/Desktop/cours/AEC-IA/MiseEnPlaceEcosystemeIA/TP-Final/Code/rl_tp.ipynb#W0sZmlsZQ%3D%3D?line=66'>67</a>     lr = ElasticNet(alpha=alpha, l1_ratio=l1_ratio, random_state=42)
#      <a href='vscode-notebook-cell:/Users/gmendozamb/Desktop/cours/AEC-IA/MiseEnPlaceEcosystemeIA/TP-Final/Code/rl_tp.ipynb#W0sZmlsZQ%3D%3D?line=67'>68</a>     lr.fit(train_x, train_y)
#
# File ~/opt/anaconda3/envs/AEC-IA/lib/python3.8/site-packages/mlflow/tracking/fluent.py:351, in start_run(run_id, experiment_id, run_name, nested, tags, description)
#     347         user_specified_tags[MLFLOW_RUN_NAME] = run_name
#     349     resolved_tags = context_registry.resolve_tags(user_specified_tags)
# --> 351     active_run_obj = client.create_run(
#     352         experiment_id=exp_id_for_run, tags=resolved_tags, run_name=run_name
#     353     )
#     355 _active_run_stack.append(ActiveRun(active_run_obj))
#     356 return _active_run_stack[-1]
#
# File ~/opt/anaconda3/envs/AEC-IA/lib/python3.8/site-packages/mlflow/tracking/client.py:280, in MlflowClient.create_run(self, experiment_id, start_time, tags, run_name)
#     229 def create_run(
#     230     self,
#     231     experiment_id: str,
#    (...)
#     234     run_name: Optional[str] = None,
#     235 ) -> Run:
#     236     """
#     237     Create a :py:class:`mlflow.entities.Run` object that can be associated with
#     238     metrics, parameters, artifacts, etc.
#    (...)
#     278         status: RUNNING
#     279     """
# --> 280     return self._tracking_client.create_run(experiment_id, start_time, tags, run_name)
#
# File ~/opt/anaconda3/envs/AEC-IA/lib/python3.8/site-packages/mlflow/tracking/_tracking_service/client.py:131, in TrackingServiceClient.create_run(self, experiment_id, start_time, tags, run_name)
#     126 # Extract user from tags
#     127 # This logic is temporary; the user_id attribute of runs is deprecated and will be removed
#     128 # in a later release.
#     129 user_id = tags.get(MLFLOW_USER, "unknown")
# --> 131 return self.store.create_run(
#     132     experiment_id=experiment_id,
#     133     user_id=user_id,
#     134     start_time=start_time or get_current_time_millis(),
#     135     tags=[RunTag(key, value) for (key, value) in tags.items()],
#     136     run_name=run_name,
#     137 )
#
# File ~/opt/anaconda3/envs/AEC-IA/lib/python3.8/site-packages/mlflow/store/tracking/rest_store.py:175, in RestStore.create_run(self, experiment_id, user_id, start_time, tags, run_name)
#     165 tag_protos = [tag.to_proto() for tag in tags]
#     166 req_body = message_to_json(
#     167     CreateRun(
#     168         experiment_id=str(experiment_id),
#    (...)
#     173     )
#     174 )
# --> 175 response_proto = self._call_endpoint(CreateRun, req_body)
#     176 run = Run.from_proto(response_proto.run)
#     177 return run
#
# File ~/opt/anaconda3/envs/AEC-IA/lib/python3.8/site-packages/mlflow/store/tracking/rest_store.py:56, in RestStore._call_endpoint(self, api, json_body)
#      54 endpoint, method = _METHOD_TO_INFO[api]
#      55 response_proto = api.Response()
# ---> 56 return call_endpoint(self.get_host_creds(), endpoint, method, json_body, response_proto)
#
# File ~/opt/anaconda3/envs/AEC-IA/lib/python3.8/site-packages/mlflow/utils/rest_utils.py:303, in call_endpoint(host_creds, endpoint, method, json_body, response_proto)
#     299 else:
#     300     response = http_request(
#     301         host_creds=host_creds, endpoint=endpoint, method=method, json=json_body
#     302     )
# --> 303 response = verify_rest_response(response, endpoint)
#     304 js_dict = json.loads(response.text)
#     305 parse_dict(js_dict=js_dict, message=response_proto)
#
# File ~/opt/anaconda3/envs/AEC-IA/lib/python3.8/site-packages/mlflow/utils/rest_utils.py:227, in verify_rest_response(response, endpoint)
#     225 if response.status_code != 200:
#     226     if _can_parse_as_json_object(response.text):
# --> 227         raise RestException(json.loads(response.text))
#     228     else:
#     229         base_msg = "API request to endpoint {} failed with error code {} != 200".format(
#     230             endpoint,
#     231             response.status_code,
#     232         )
#
# RestException: RESOURCE_DOES_NOT_EXIST: No Experiment with id=970865909611407138 exists
